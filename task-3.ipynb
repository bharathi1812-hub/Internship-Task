# %%
import random
def guess_number():
    number = random.randint(1, 100)
    attempts = 0
    print("I have chosen a number between 1 and 100. Can you guess it?")
    while True:
        guess = int(input("Enter your guess: "))
        attempts +=1
        if guess < number:
            print("Too low! Try again.")
        elif guess > number:
            print("Too high! Try again.")
        else:
            print(f"🎉 Correct! The number was {number}. You guessed it in {attempts} attempts.")
            break

guess_number()
# Out:
# I have chosen a number between 1 and 100. Can you guess it?
# Enter your guess:  13
# Too low! Try again.
# Enter your guess:  29
# Too low! Try again.
# Enter your guess:  36
# Too high! Try again.
# Enter your guess:  34
# Too high! Try again.
# Enter your guess:  33
# Too high! Try again.
# Enter your guess:  31
# Too low! Try again.
# Enter your guess:  32
#  Correct! The number was 32. You guessed it in 7 attempts.
